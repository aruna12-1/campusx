# %%
import numpy as np
a=np.array([1,2,3,4,5])
print(a)
# Out:
# [1 2 3 4 5]

# %%
import numpy as np

a = np.array([1, 2, 3, 4, 5, 6])
print(a)

b = a.reshape(2, 3)
print(b)
# Out:
# [1 2 3 4 5 6]
# [[1 2 3]
#  [4 5 6]]

# %%
import numpy as np

a = np.array([[1, 2, 3],
              [4, 5, 6]])

print(a.ravel())
# Out:
# [1 2 3 4 5 6]

# %%
a.resize(3,2)
print(a)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
