# %%
from sklearn.linear_model import *
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data=pd.read_csv('placement.csv')
data.head()

x=data[['cgpa','resume_score']]
y=data['placed']
p=Perceptron()
p.fit(x,y)
# Out:
# Perceptron()

# %%
weights=p.coef_[0]
weights
bias=p.intercept_[0]
bias
# Out:
# np.float64(-25.0)

# %%
data
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
p.coef_[0]
# Out:
# array([ 40.26, -36.  ])

# %%
plt.scatter(data['cgpa'],data['resume_score'],c=data['placed'])

# %%
X = data.iloc[:,0:2]
y = data.iloc[:,-1]

# %%
y
# Out:
# 0     1
# 1     0
# 2     1
# 3     1
# 4     1
#      ..
# 95    0
# 96    1
# 97    0
# 98    1
# 99    0
# Name: placed, Length: 100, dtype: int64

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X.values, y.values, clf=p, legend=2)
# Out:
# c:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
